# %% [markdown]
# # IMPORTING MODULES

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("/Users/adhidevmullaratte/Downloads/Sleep_health_and_lifestyle_dataset.csv")

# %%
df.head(100)
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0           1    Male   27     Software Engineer             6.1
# 1           2    Male   28                Doctor             6.2
# 2           3    Male   28                Doctor             6.2
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# ..        ...     ...  ...                   ...             ...
# 95         96  Female   36            Accountant             7.1
# 96         97  Female   36            Accountant             7.2
# 97         98  Female   36            Accountant             7.1
# 98         99  Female   36               Teacher             7.1
# 99        100  Female   36               Teacher             7.1
#
#     Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                  6                       42             6   Overweight
# ...

# %%
df.shape
# Out:
# (374, 13)

# %% [markdown]
# # DEALING WITH NULL VALUES

# %%
df.isnull().any()
# Out:
# Person ID                  False
# Gender                     False
# Age                        False
# Occupation                 False
# Sleep Duration             False
# Quality of Sleep           False
# Physical Activity Level    False
# Stress Level               False
# BMI Category               False
# Blood Pressure             False
# Heart Rate                 False
# Daily Steps                False
# Sleep Disorder              True
# dtype: bool

# %%
df1=df.isnull()

# %%
plt.figure(figsize=(10, 8))  
sns.heatmap(df1,cmap='coolwarm', )  
plt.title('null value visualzation')  
plt.show()

# %%
df['Sleep Disorder'].unique()
# Out:
# array([nan, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df['Sleep Disorder'].fillna("normal", inplace=True)

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200         normal
# ...

# %%
df.isnull().any()
# Out:
# Person ID                  False
# Gender                     False
# Age                        False
# Occupation                 False
# Sleep Duration             False
# Quality of Sleep           False
# Physical Activity Level    False
# Stress Level               False
# BMI Category               False
# Blood Pressure             False
# Heart Rate                 False
# Daily Steps                False
# Sleep Disorder             False
# dtype: bool

# %%
df2=df.isnull()

# %%
plt.figure(figsize=(10, 8))  
sns.heatmap(df2,cmap='coolwarm', )  
plt.title('null value visualzation')  
plt.show()

# %% [markdown]
# # CHECKING DUPLICATE VALUES

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Person ID, Gender, Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Daily Steps, Sleep Disorder]
# Index: []

# %% [markdown]
# # statistical analysis

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df.nunique()
# Out:
# Person ID                  374
# Gender                       2
# Age                         31
# Occupation                  11
# Sleep Duration              27
# Quality of Sleep             6
# Physical Activity Level     16
# Stress Level                 6
# BMI Category                 4
# Blood Pressure              25
# Heart Rate                  19
# Daily Steps                 20
# Sleep Disorder               3
# dtype: int64

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %% [markdown]
# # spliting the column Blood Pressure

# %%
df[["high Blood Pressure", "low Blood Pressure"]] = df["Blood Pressure"].str.split("/", expand=True)

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder high Blood Pressure  \
# ...

# %%
high_bp_column = df['high Blood Pressure']
print(high_bp_column.dtype)
# Out:
# object

# %%
df['high Blood Pressure'] = df['high Blood Pressure'].astype(int)

# %%
df['low Blood Pressure'] = df['low Blood Pressure'].astype(int)

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# high Blood Pressure          int64
# low Blood Pressure           int64
# dtype: object

# %%
df.drop(columns=['Blood Pressure'], inplace=True)

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# high Blood Pressure          int64
# low Blood Pressure           int64
# dtype: object

# %% [markdown]
# # finding the garbage value

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("garbage value")
# Out:
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64
# garbage value
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64
# garbage value
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64
# garbage value
# Sleep Disorder
# normal         219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64
# garbage value

# %% [markdown]
# # finding outliers

# %%
def wisker(col):
    q1, q3 = np.percentile(col, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return lower_bound, upper_bound

# %%
for i in df.select_dtypes(include="number").columns:
    plt.figure(figsize=(10, 8)) 
    sns.boxplot(data=df[i])
    plt.title(i)  
    plt.show()

# %% [markdown]
# # comparison by gender

# %%
columns_to_plot = ['Quality of Sleep', 'Sleep Duration', 'Stress Level']


for column in columns_to_plot:
    plt.figure(figsize=(8, 6))
    sns.barplot(data=df, x='Gender', y=column)
    plt.title(f'{column} by Gender')
    plt.xlabel('Gender')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# comparison by age

# %%
columns_to_plot = ['Quality of Sleep', 'Sleep Duration', 'Stress Level']
for column in columns_to_plot:
  plt.figure(figsize=(8, 6))
  sns.lineplot(x='Age', y=column, data=df)  
  plt.title(f'{column} by Age')
  plt.xlabel('Age')
  plt.ylabel(column)
  plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # comparison of occupation and bmi category

# %%
cross_tab = pd.crosstab(df['Occupation'], df['BMI Category'])

# Plotting a stacked bar chart
plt.figure(figsize=(8, 6))
cross_tab.plot(kind='bar', stacked=True)
plt.title('Comparison of Occupation and BMI Category')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='BMI Category')
plt.show()

# %% [markdown]
# # comparison of bmi category with physical activities

# %%
    plt.figure(figsize=(8, 6))
    sns.barplot(data=df, x='BMI Category', y='Physical Activity Level')
    plt.title('Comparison of BMI Category and Physical Activity Level')
    plt.xlabel('Comparison of BMI Category')
    plt.ylabel('Physical Activity Level')
    plt.show()

# %% [markdown]
# # DATA ENCODING

# %%
dummy=pd.get_dummies(data=df,columns=['Gender','Occupation','BMI Category','Sleep Disorder'],drop_first=True)

# %%
dummy
# Out:
#      Person ID  Age  Sleep Duration  Quality of Sleep  \
# 0            1   27             6.1                 6
# 1            2   28             6.2                 6
# 2            3   28             6.2                 6
# 3            4   28             5.9                 4
# 4            5   28             5.9                 4
# ..         ...  ...             ...               ...
# 369        370   59             8.1                 9
# 370        371   59             8.0                 9
# 371        372   59             8.1                 9
# 372        373   59             8.1                 9
# 373        374   59             8.1                 9
#
#      Physical Activity Level  Stress Level  Heart Rate  Daily Steps  \
# 0                         42             6          77         4200
# 1                         60             8          75        10000
# 2                         60             8          75        10000
# ...
